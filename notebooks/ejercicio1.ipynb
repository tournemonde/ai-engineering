# %% [markdown]
# # Ejercicio 1 AI-Engineering

# %% [markdown]
# ## Instalar librerías

# %%
# %pip -q install openai

# %%
# %pip -q install anthropic

# %%
# %pip install -q python-dotenv

# %% [markdown]
# ### Load env variables

# %%
from pathlib import Path
from dotenv import load_dotenv

# Resolves relative to wherever this notebook is on the runtime
notebook_dir = Path().resolve()
print("notebook_dir:", notebook_dir)
dotenv_path = notebook_dir.parent / ".env"

print("Looking for .env at:", dotenv_path)
print("Exists:", dotenv_path.exists())
load_dotenv(dotenv_path=dotenv_path)
# Out:
# notebook_dir: /content
# Looking for .env at: /.env
# Exists: False
# False

# %%
import os
print(os.environ.get("OPENAI_API_KEY"))
# Out:
# None

# %%
import os
from pathlib import Path

print("cwd:", os.getcwd())
print("../. env resolves to:", Path("../.env").resolve())
print("exists:", Path("../.env").resolve().exists())
# Out:
# cwd: /content
# ../. env resolves to: /.env
# exists: False
